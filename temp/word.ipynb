# %%
"""
from wordcloud import WordCloud
import matplotlib.pyplot as plt 

text = ("this is a book, this is a book, this is a book, this is a book this is a book this is a book this is a bookthis is a bookthis is a book ")
wc = WordCloud().generate(text)
plt.imshow()
"""
# Out:
# '\nfrom wordcloud import WordCloud\nimport matplotlib.pyplot as plt \n\ntext = ("this is a book, this is a book, this is a book, this is a book this is a book this is a book this is a bookthis is a bookthis is a book ")\nwc = WordCloud().generate(text)\nplt.imshow()\n'

# %%
# Python program to generate WordCloud
 
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file 
df = pd.read_csv(r"annual-enterprise-survey-2021-financial-year-provisional-csv.csv", encoding ="latin-1")
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.CONTENT:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12928/770333786.py in ?()
# ---> 15 # Python program to generate WordCloud
#      16
#      17 # importing all necessary modules
#      18 from wordcloud import WordCloud, STOPWORDS
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'CONTENT'
